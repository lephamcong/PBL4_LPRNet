# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/PBL4_LPRNet/LPRNet_Pytorch_China
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/PBL4_LPRNet/LPRNet_Pytorch_China

# %%
# !pip install torchsummary
# !python summary.py
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.10/dist-packages (1.5.1)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 22, 92]           1,792
#        BatchNorm2d-2           [-1, 64, 22, 92]             128
#               ReLU-3           [-1, 64, 22, 92]               0
#          MaxPool3d-4           [-1, 64, 20, 90]               0
#             Conv2d-5           [-1, 32, 20, 90]           2,080
#               ReLU-6           [-1, 32, 20, 90]               0
#             Conv2d-7           [-1, 32, 20, 90]           3,104
#               ReLU-8           [-1, 32, 20, 90]               0
#             Conv2d-9           [-1, 32, 20, 90]           3,104
#              ReLU-10           [-1, 32, 20, 90]               0
#            Conv2d-11          [-1, 128, 20, 90]           4,224
# small_basic_block-12          [-1, 128, 20, 90]               0
#       BatchNorm2d-13          [-1, 128, 20, 90]             256
#              ReLU-14          [-1, 128, 20, 90]               0
#         MaxPool3d-15           [-1, 64, 18, 44]               0
#            Conv2d-16           [-1, 64, 18, 44]           4,160
#              ReLU-17           [-1, 64, 18, 44]               0
#            Conv2d-18           [-1, 64, 18, 44]          12,352
#              ReLU-19           [-1, 64, 18, 44]               0
#            Conv2d-20           [-1, 64, 18, 44]          12,352
#              ReLU-21           [-1, 64, 18, 44]               0
#            Conv2d-22          [-1, 256, 18, 44]          16,640
# small_basic_block-23          [-1, 256, 18, 44]               0
#       BatchNorm2d-24          [-1, 256, 18, 44]             512
#              ReLU-25          [-1, 256, 18, 44]               0
#            Conv2d-26           [-1, 64, 18, 44]          16,448
#              ReLU-27           [-1, 64, 18, 44]               0
#            Conv2d-28           [-1, 64, 18, 44]          12,352
#              ReLU-29           [-1, 64, 18, 44]               0
#            Conv2d-30           [-1, 64, 18, 44]          12,352
#              ReLU-31           [-1, 64, 18, 44]               0
#            Conv2d-32          [-1, 256, 18, 44]          16,640
# small_basic_block-33          [-1, 256, 18, 44]               0
#       BatchNorm2d-34          [-1, 256, 18, 44]             512
#              ReLU-35          [-1, 256, 18, 44]               0
#         MaxPool3d-36           [-1, 64, 16, 21]               0
#           Dropout-37           [-1, 64, 16, 21]               0
#            Conv2d-38          [-1, 256, 16, 18]          65,792
#       BatchNorm2d-39          [-1, 256, 16, 18]             512
#              ReLU-40          [-1, 256, 16, 18]               0
#           Dropout-41          [-1, 256, 16, 18]               0
#            Conv2d-42            [-1, 68, 4, 18]         226,372
#       BatchNorm2d-43            [-1, 68, 4, 18]             136
#              ReLU-44            [-1, 68, 4, 18]               0
#            Conv2d-45            [-1, 68, 4, 18]          35,156
# ================================================================
# Total params: 446,976
# Trainable params: 446,976
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 33.64
# Params size (MB): 1.71
# Estimated Total Size (MB): 35.37
# ----------------------------------------------------------------

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.901 [901:58:41:1000]
# [Info] Mean Levenshtein Distance: 0.045
# [Info] Test Speed: 0.005114774703979492s 1/1000]
#
# Sample Predictions and Levenshtein Distances:
# Figure(640x480)
# target:  皖A256R2  ### T ###  predict:  皖A256R2
# Predicted: 皖A256R2, Target: 皖A256R2, Levenshtein Distance: 0
# Figure(640x480)
# target:  皖AGG131  ### T ###  predict:  皖AGG131
# Predicted: 皖AGG131, Target: 皖AGG131, Levenshtein Distance: 0
# Figure(640x480)
# target:  皖AHX502  ### T ###  predict:  皖AHX502
# Predicted: 皖AHX502, Target: 皖AHX502, Levenshtein Distance: 0

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.901 [901:58:41:1000]
# [Info] Mean Levenshtein Distance: 0.045
# [Info] Test Speed: 0.009558125734329223s 1/1000]
#
# Sample Predictions and Levenshtein Distances:
# Figure(640x480)
# target:  皖AM190J  ### T ###  predict:  皖AM190J
# Predicted: 皖AM190J, Target: 皖AM190J, Levenshtein Distance: 0
# Figure(640x480)
# target:  皖AN3593  ### T ###  predict:  皖AN3593
# Predicted: 皖AN3593, Target: 皖AN3593, Levenshtein Distance: 0
# Figure(640x480)
# target:  皖A506T7  ### F ###  predict:  皖AJ06T7
# Predicted: 皖AJ06T7, Target: 皖A506T7, Levenshtein Distance: 1

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.899 [899:59:42:1000]
# [Info] Mean Levenshtein Distance: 0.046
# [Info] Test Speed: 0.010425460815429688s 1/1000]
#
# Sample Predictions and Levenshtein Distances:
# Figure(640x480)
# target:  皖M04698  ### T ###  predict:  皖M04698
# Predicted: 皖M04698, Target: 皖M04698, Levenshtein Distance: 0
# Figure(640x480)
# target:  皖AT582T  ### T ###  predict:  皖AT582T
# Predicted: 皖AT582T, Target: 皖AT582T, Levenshtein Distance: 0
# Figure(640x480)
# target:  皖D93138  ### T ###  predict:  皖D93138
# Predicted: 皖D93138, Target: 皖D93138, Levenshtein Distance: 0
# Figure(640x480)
# Figure(640x480)

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.898 [898:64:38:1000]
# [Info] Mean Levenshtein Distance: 0.041
# [Info] Test Speed: 0.010418030500411988s 1/1000]
#
# Sample Predictions and Levenshtein Distances:
# Đã lưu ảnh vào: output/皖ALD252_T_皖ALD252.jpg
# target:  皖ALD252  ### T ###  predict:  皖ALD252
# Predicted: 皖ALD252, Target: 皖ALD252, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/皖AB113D_T_皖AB113D.jpg
# target:  皖AB113D  ### T ###  predict:  皖AB113D
# Predicted: 皖AB113D, Target: 皖AB113D, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/皖AE2471_T_皖AE2471.jpg
# target:  皖AE2471  ### T ###  predict:  皖AE2471
# Predicted: 皖AE2471, Target: 皖AE2471, Levenshtein Distance: 0

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.9 [900:61:39:1000]
# [Info] Mean Levenshtein Distance: 0.042
# [Info] Test Speed: 0.24238528561592101s 1/1000]
#
# Sample Predictions and Levenshtein Distances:
# Đã lưu ảnh vào: output/皖NG3660_T_皖NG3660.jpg
# target:  皖NG3660  ### T ###  predict:  皖NG3660
# Predicted: 皖NG3660, Target: 皖NG3660, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/皖AB287L_T_皖AB287L.jpg
# target:  皖AB287L  ### T ###  predict:  皖AB287L
# Predicted: 皖AB287L, Target: 皖AB287L, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/皖AWU931_T_皖AWU931.jpg
# target:  皖AWU931  ### T ###  predict:  皖AWU931
# Predicted: 皖AWU931, Target: 皖AWU931, Levenshtein Distance: 0

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.897 [897:64:39:1000]
# [Info] Mean Levenshtein Distance: 0.042
# [Info] Test Speed: 0.2104880599975586s 1/1000]
#
# Sample Predictions and Levenshtein Distances:
# Đã lưu ảnh vào: output/皖AE1Z11_T_皖AE1Z11.jpg
# target:  皖AE1Z11  ### T ###  predict:  皖AE1Z11
# Predicted: 皖AE1Z11, Target: 皖AE1Z11, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/皖AGG512_T_皖AGG512.jpg
# target:  皖AGG512  ### T ###  predict:  皖AGG512
# Predicted: 皖AGG512, Target: 皖AGG512, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/皖AXQ959_T_皖AXQ959.jpg
# target:  皖AXQ959  ### T ###  predict:  皖AXQ959
# Predicted: 皖AXQ959, Target: 皖AXQ959, Levenshtein Distance: 0
