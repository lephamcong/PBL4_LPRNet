# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/PBL4_LPRNet/LPRNet_Pytorch_VietNam
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/PBL4_LPRNet/LPRNet_Pytorch_VietNam

# %%
# !pip install torchsummary

# %%
# !python train_LPRNet.py
# Out:
# Successful to build network!
# initial net weights successful!
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch:1 || epochiter: 0/385|| Totel iter 0 || Loss: 69.6602||Batch time: 10.3181 sec. ||LR: 0.00100000
# ...

# %%
# !python summary.py
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 22, 92]           1,792
#        BatchNorm2d-2           [-1, 64, 22, 92]             128
#               ReLU-3           [-1, 64, 22, 92]               0
#          MaxPool3d-4           [-1, 64, 20, 90]               0
#             Conv2d-5           [-1, 32, 20, 90]           2,080
#               ReLU-6           [-1, 32, 20, 90]               0
#             Conv2d-7           [-1, 32, 20, 90]           3,104
#               ReLU-8           [-1, 32, 20, 90]               0
#             Conv2d-9           [-1, 32, 20, 90]           3,104
#              ReLU-10           [-1, 32, 20, 90]               0
#            Conv2d-11          [-1, 128, 20, 90]           4,224
# small_basic_block-12          [-1, 128, 20, 90]               0
#       BatchNorm2d-13          [-1, 128, 20, 90]             256
# ...

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.749 [749:166:85:1000]
# [Info] Test Speed: 0.005804772615432739s 1/1000]

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.751 [751:165:84:1000]
# [Info] Test Speed: 0.010879188060760499s 1/1000]

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.75 [750:164:86:1000]
# [Info] Test Speed: 0.010597337007522583s 1/1000]

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.746 [746:165:89:1000]
# [Info] Mean Levenshtein Distance: 0.156
# [Info] Test Speed: 0.2175088245868683s 1/1000]
# [Info] Avg Inference Time per Sample: 0.2175086348056793s
#
# Sample Predictions and Levenshtein Distances:
# Đã lưu ảnh vào: output/30A20388_T_30A20388.jpg
# target:  30A20388  ### T ###  predict:  30A20388
# Predicted: 30A20388, Target: 30A20388, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/18A12345_T_18A12345.jpg
# target:  18A12345  ### T ###  predict:  18A12345
# Predicted: 18A12345, Target: 18A12345, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/29A51796_T_29A51796.jpg
# target:  29A51796  ### T ###  predict:  29A51796
# Predicted: 29A51796, Target: 29A51796, Levenshtein Distance: 0

# %%
# !python test_LPRNet.py
# Out:
# Successful to build network!
# load pretrained model successful!
# [Info] Test Accuracy: 0.744 [744:168:88:1000]
# [Info] Mean Levenshtein Distance: 0.155
# [Info] Test Speed: 0.15080265855789185s 1/1000]
# [Info] Avg Inference Time per Sample: 0.15080252027511595s
#
# Sample Predictions and Levenshtein Distances:
# Đã lưu ảnh vào: output/29T2471_F_2912471.jpg
# target:  29T2471  ### F ###  predict:  2912471
# Predicted: 2912471, Target: 29T2471, Levenshtein Distance: 1
# Đã lưu ảnh vào: output/30A34588_T_30A34588.jpg
# target:  30A34588  ### T ###  predict:  30A34588
# Predicted: 30A34588, Target: 30A34588, Levenshtein Distance: 0
# Đã lưu ảnh vào: output/21A08531_T_21A08531.jpg
# target:  21A08531  ### T ###  predict:  21A08531
# Predicted: 21A08531, Target: 21A08531, Levenshtein Distance: 0
